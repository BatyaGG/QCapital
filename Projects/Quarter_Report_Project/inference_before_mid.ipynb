# %%
import numpy as np
import pandas as pd
from tqdm import tqdm_notebook
import warnings
warnings.filterwarnings("ignore")
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import r2_score,matthews_corrcoef,accuracy_score, confusion_matrix, recall_score, roc_auc_score, precision_score, f1_score
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.base import clone
import random
import math
from datetime import timedelta
import pickle

# %%
with open('updated_mid_raw_tickers.dictionary', 'rb') as config_dictionary_file:
 
    # Step 3
    combined = pickle.load(config_dictionary_file)

# %%
b4rep_window = 10
thr = 0.65

# %%
def compress(series, sides=0.01):
    
    series = pd.Series(np.where( series > series.quantile(q=(1-sides)) , series.quantile(q=(1-sides)), series ), 
                      index=series.index)
    series = np.where( series < series.quantile(q=sides), series.quantile(q=sides), series)
    return series

def compress_right_tail(series, sides=0.01):
    
    series = pd.Series(np.where( series > series.quantile(q=(1-sides)) , series.quantile(q=(1-sides)), series ), 
                      index=series.index)
    return series

def create_features(dtf, tick, lead=5, ret_lag=[1,2,5,10,20,44,261], tr=0.025, vol_lag=[1,2,5,10,20,44,261], vol_window=100, sides=0.01):
    
    feat_cols = []
#    dtf['volume'] = np.log(dtf['volume'])

#    dtf['volume'] = (dtf['volume']-dtf['volume'].cummin())/(dtf['volume'].cummax()-dtf['volume'].cummin())

    avg_vol_name = 'avg_vol_' + str(vol_window)
    dtf[avg_vol_name] = dtf['volume'].rolling(window=vol_window).mean()
    dtf[avg_vol_name] = np.log(dtf[avg_vol_name])
#     avg_range_name = 'avg_range_' + str(vol_window)
#     dtf[avg_range_name] = np.abs(dtf['high'].rolling(window=vol_window).mean()-dtf['low'].rolling(window=vol_window).mean())
#     dtf[avg_range_name] = compress(dtf[avg_range_name], sides=sides)

# #     avg_low_name = 'avg_low_' + str(vol_window)
# #     dtf[avg_low_name] = dtf[tick]-dtf['low'].rolling(window=vol_window).mean()
# #     avg_high_name = 'avg_high_' + str(vol_window)
# #     dtf[avg_high_name] = dtf['high'].rolling(window=vol_window).mean()-dtf[tick]
    
#     for avg in vol_avgs:

#         name_simple = 'open'+str(avg)
#         dtf[name_simple] = dtf['open'].rolling(window=avg).mean()
#         dtf[name_simple] = np.log(dtf[name_simple])
#         dtf[name_simple] = compress(dtf[name_simple], sides=sides)
#         dtf[name_simple] = (dtf[name_simple]-dtf[name_simple].min()) / (dtf[name_simple].max() - dtf[name_simple].min())
#         feat_cols.append(name_simple)
#         name_simple = 'high'+str(avg)
#         dtf[name_simple] = dtf['high'].rolling(window=avg).mean()
#         dtf[name_simple] = np.log(dtf[name_simple])
#         dtf[name_simple] = compress(dtf[name_simple], sides=sides)
#         dtf[name_simple] = (dtf[name_simple]-dtf[name_simple].min()) / (dtf[name_simple].max() - dtf[name_simple].min())
#         #feat_cols.append(name_simple)
#         name_simple = 'low'+str(avg)
#         dtf[name_simple] = dtf['low'].rolling(window=avg).mean()
#         dtf[name_simple] = np.log(dtf[name_simple])
#         dtf[name_simple] = compress(dtf[name_simple], sides=sides)
#         dtf[name_simple] = (dtf[name_simple]-dtf[name_simple].min()) / (dtf[name_simple].max() - dtf[name_simple].min())
#         #feat_cols.append(name_simple)
# #         name_simple = 'vwap'+str(avg)
# #         dtf[name_simple] = dtf['vwap'].rolling(window=avg).mean()
# #         dtf[name_simple] = np.log(dtf[name_simple])
# #         dtf[name_simple] = compress(dtf[name_simple], sides=sides)
# #         dtf[name_simple] = (dtf[name_simple]-dtf[name_simple].min()) / (dtf[name_simple].max() - dtf[name_simple].min())
# #         feat_cols.append(name_simple)
#         name_simple = 'ranges'+str(avg)
#         dtf[name_simple] = np.abs(dtf['high'+str(avg)]-dtf['low'+str(avg)])
#         dtf[name_simple] = compress(dtf[name_simple], sides=sides)
#         dtf[name_simple] = dtf[name_simple] / dtf[avg_range_name]
#         dtf[name_simple] = compress(dtf[name_simple], sides=sides)
#         #feat_cols.append(name_simple)


    
    
    for lag in vol_lag:
        name_simple = 'vol'+str(lag)
        dtf[name_simple] = dtf['volume'].rolling(window=lag).mean()
        dtf[name_simple] = np.log(dtf[name_simple])
        dtf[name_simple] = dtf[name_simple] / dtf[avg_vol_name]
        dtf[name_simple] = compress(dtf[name_simple], sides=sides)
        dtf[name_simple] = (dtf[name_simple]-dtf[name_simple].cummin()) / (dtf[name_simple].cummax() - dtf[name_simple].cummin())
        feat_cols.append(name_simple)
    for lag in ret_lag:
        name = 'ret'+str(lag)
        dtf[name] = dtf[tick]/dtf[tick].shift(lag)-1
        dtf[name] = compress(dtf[name], sides=sides)
        dtf[name] = (dtf[name] - dtf[name].cummin()) / (dtf[name].cummax() - dtf[name].cummin())
        feat_cols.append(name)

        
        
    dtf['tick'] = tick
    #feat_cols.append(tick)
#    dtf['fwd'] = dtf[tick].shift(-lead+1) / dtf[tick]-1
#    dtf['fwd'] = dtf[tick].shift(-lead) / dtf[tick]-1
    dtf['fwd'] = dtf[tick].shift(-lead-1) / dtf[tick]-1
    dtf['ycol'] = np.where(dtf['fwd'] >= tr, 1, 0)
    feat_cols.append('ycol')
#    dtf['mva_90'] = dtf[tick].rolling(window=90).mean()
#    dtf['y_90'] = np.where(dtf[tick] >= dtf['mva_90'], 1, 0)
#    feat_cols.append('y_90')
    return dtf, feat_cols

def ticker_features(combined_dtfs, ticker, growth_tr=0.02, back_window=28, b4rep_window=10,
                   ret_lag=[1,2,5,10,20,44,261], vol_lag=[1,2,5,10,20,44,261], vol_window=100, sides=0.01):

    idf = combined_dtfs[ticker]
    if combined[ticker].shape[0]==0:
        return
    else:
        idf['idate'] = idf.index
        idf['idate'] = idf['idate'].shift(1)
        idf['b4rep_window'] = idf.index
        idf['b4rep_window'] = idf['b4rep_window'].shift(b4rep_window+1)
        #print(ticker)
        idf['back_window'] = pd.to_datetime(np.where(idf.rep_date == 1, idf['idate'] - \
                                                     pd.Timedelta(days=back_window), pd.to_datetime(np.nan)))
        idf['back_window'] = idf['back_window'].fillna(method='backfill')

        idf['b4rep_window'] = pd.to_datetime(np.where(idf.rep_date == 1, idf['b4rep_window'], pd.to_datetime(np.nan)))
        idf['b4rep_window'] = idf['b4rep_window'].fillna(method='backfill')

        idf['b4rep'] = np.where( idf.idate >= idf.back_window , 1, 0 )
        idf['next_rep'] = pd.to_datetime(np.where( idf.rep_date == 1, idf.idate, pd.to_datetime(np.nan)))
        idf['next_rep'] = idf['next_rep'].fillna(method='backfill')
        idf['price_atrep'] = idf['next_rep'].map(idf[ticker])
        idf['price_b4rep'] = idf['b4rep_window'].map(idf[ticker])
        idf['b4rep_chng'] = idf['price_atrep']/idf['price_b4rep']-1

        #idf = idf[idf.b4rep == 1]#[['meli', 'volume', 'rep_date']]
        #idf['ycol'] = np.where( (idf['b4rep'] == 1) & (idf['b4rep_chng'] > growth_tr), 1, 0 )
        #idf = idf[[ticker, 'volume', 'b4rep', 'b4rep_chng']]

        #idf = create_returns(idf, ticker, lead=b4rep_window, tr=growth_tr)
        idf, feat_cols = create_features(idf, ticker, lead=b4rep_window,ret_lag=ret_lag, vol_lag=vol_lag, tr=growth_tr, 
                            vol_window=vol_window, sides=sides)
        feat_cols.append('fwd')
        feat_cols.append('tick')
        idf = idf[idf.idate == idf.b4rep_window]

        return idf[feat_cols].dropna()
def nasdaq_features(combined, params=None):
    
    if params == None:
        params = {
            'b4rep_window': b4rep_window, 
            'growth_tr': 0.02,
            'back_window': 28, 
            'ret_lag': [1,2,5,10,22,44,51,66,118,132,246,261,375,480,520], 
            'vol_lag': [1,2,5,10,22,44,51,66,118,132], 
            'vol_window': 100, 
            'sides': 0.01
        }
    
    df = pd.DataFrame()
    for i in combined:
        df = df.append(ticker_features(combined, i, **params))
    df = df.sort_index()
    
    return df

# %%
# %%time
df = nasdaq_features(combined, params=None)
#### ADDED COLUMN FOR TESTING RETURNS
#df['case_id'] = np.linspace(1, df.shape[0], df.shape[0])
df.index = df.index
df['date:tick'] = df.index.astype(str)+':'+df['tick']

#### ALSO AMENDED my_tss function to account for new column
df.head()
# Out:
# CPU times: user 33.7 s, sys: 184 ms, total: 33.8 s
# Wall time: 33.9 s
#                 vol1      vol2      vol5     vol10     vol22     vol44  \
# 2002-02-01  0.520735  0.553674  0.627800  0.805963  0.847464  0.887232
# 2002-02-05  0.431302  0.479171  0.000000  0.000000  0.039793  0.109718
# 2002-02-05  0.480296  0.470399  0.538486  0.141694  0.240743  0.003635
# 2002-02-05  0.158040  0.301677  0.277521  0.300602  0.289138  0.334693
# 2002-02-11  0.509447  0.616043  0.454173  0.517911  0.508214  0.657546
#
#                vol51     vol66    vol118    vol132  ...    ret132    ret246  \
# 2002-02-01  0.964082  0.386751  0.938787  0.964084  ...  0.308752  0.221616
# 2002-02-05  0.130907  0.227047  0.455813  0.659656  ...  0.447544  0.332483
# 2002-02-05  0.000000  0.045914  0.675900  0.837344  ...  0.303974  0.079071
# 2002-02-05  0.372043  0.472216  0.612167  0.499342  ...  0.517301  0.394961
# 2002-02-11  0.522989  0.452308  0.766881  0.804940  ...  0.688424  0.578354
#
#               ret261    ret375    ret480    ret520  ycol       fwd  tick  \
# 2002-02-01  0.136592  0.245488  0.396372  1.000000     1  0.028706   sxt
# 2002-02-05  0.371083  0.863058  0.000000  0.766544     0 -0.040737   dci
# 2002-02-05  0.281811  0.111068  0.828080  1.000000     0 -0.000746  ndsn
# 2002-02-05  0.399169  0.374585  0.000000  0.000000     0 -0.056228   arw
# 2002-02-11  0.586273  0.910341  0.155651  0.334553     0 -0.004570  pzza
#
#                   date:tick
# 2002-02-01   2002-02-01:sxt
# 2002-02-05   2002-02-05:dci
# 2002-02-05  2002-02-05:ndsn
# 2002-02-05   2002-02-05:arw
# 2002-02-11  2002-02-11:pzza
#
# [5 rows x 29 columns]

# %%
# save the model to disk
filename = 'inference_before_mid.sav'
 
# some time later...
 
# load the model from disk
estimatorCopy = pickle.load(open(filename, 'rb'))
#result = estimatorCopy.score(validx, validy)
print(estimatorCopy)
# Out:
# RandomForestClassifier(bootstrap=False, criterion='entropy',
#                        max_features=0.7428567749319119, min_samples_leaf=4,
#                        n_estimators=299, n_jobs=-1, random_state=1,
#                        verbose=False)

# %%
cols=['vol1', 'vol2', 'vol5', 'vol10', 'vol22', 'vol44', 'vol51', 'vol66',
       'vol118', 'vol132', 'ret1', 'ret2', 'ret5', 'ret10', 'ret22', 'ret44',
       'ret51', 'ret66', 'ret118', 'ret132', 'ret246', 'ret261', 'ret375',
       'ret480', 'ret520']
num_companies=400
next_reports = df['tick'][-int(num_companies*1.3):]
ticker_proba = {}
existing_reports = []
for ticker in next_reports:
    try:
        pred_features=combined[ticker][-1:][cols]
        ticker_proba[ticker] = estimatorCopy.predict_proba(pred_features)[:,2]
        existing_reports.append(ticker)
    except:
        print('except:')
        print(ticker)
# Out:
# except:
# tdy

# %%
{k: v for k, v in sorted(ticker_proba.items(), key=lambda item: item[1],reverse=True)}
# Out:
# {'trmk': array([0.75070075]),
#  'cfr': array([0.69554865]),
#  'dhc': array([0.66651537]),
#  'enr': array([0.65672082]),
#  'tho': array([0.65206243]),
#  'alex': array([0.65179965]),
#  'oge': array([0.65134576]),
#  'safm': array([0.64566014]),
#  'fult': array([0.64473642]),
#  'ale': array([0.61901577]),
#  'iboc': array([0.6173276]),
#  'blkb': array([0.60685619]),
#  'fnb': array([0.60114668]),
#  'chdn': array([0.58150979]),
#  'svc': array([0.57821309]),
#  'rig': array([0.57748049]),
#  'pacw': array([0.57249562]),
#  'y': array([0.57060041]),
#  'vly': array([0.56523332]),
#  'boh': array([0.56260551]),
#  'wwd': array([0.56137124]),
#  'cxw': array([0.55784361]),
#  'pbf': array([0.55680045]),
#  'msm': array([0.55458672]),
#  'mdp': array([0.54968944]),
#  'krc': array([0.54577162]),
#  'knx': array([0.54438605]),
#  'mur': array([0.54138398]),
#  'sabr': array([0.51944577]),
#  'ghc': array([0.51917503]),
#  'livn': array([0.51881669]),
#  'ter': array([0.5173276]),
#  'ugi': array([0.51383978]),
#  'hain': array([0.51196847]),
#  'amcx': array([0.50781175]),
#  'ncr': array([0.50692785]),
#  'cnk': array([0.50602007]),
#  'pten': array([0.50543876]),
#  'nnn': array([0.50208632]),
#  'cc': array([0.50019908]),
#  'skt': array([0.49828794]),
#  'csl': array([0.49439401]),
#  'jblu': array([0.49394012]),
#  'pri': array([0.48860487]),
#  'tco': array([0.48367574]),
#  'swx': array([0.48311833]),
#  'dei': array([0.48185221]),
#  'snv': array([0.48182832]),
#  'dlx': array([0.47630196]),
#  'aeo': array([0.47624622]),
#  'ori': array([0.47134098]),
#  'ewbc': array([0.47111005]),
#  'fcn': array([0.47081542]),
#  'jbgs': array([0.47074375]),
#  'wex': array([0.46861761]),
#  'kex': array([0.46844243]),
#  'umpq': array([0.46068642]),
#  'txrh': array([0.4605829]),
#  'faf': array([0.45902214]),
#  'rgld': array([0.45806657]),
#  'hwc': array([0.45684026]),
#  'mac': array([0.45655359]),
#  'asb': array([0.4563147]),
#  'avt': array([0.4555821]),
#  'int': array([0.45452301]),
#  'epc': array([0.45436375]),
#  'cake': array([0.45147316]),
#  'bco': array([0.44757923]),
#  'gmed': array([0.44695015]),
#  'ofc': array([0.44629718]),
#  'bxs': array([0.44473642]),
#  'wafd': array([0.44466476]),
#  'md': array([0.44182195]),
#  'smg': array([0.440301]),
#  'tdc': array([0.43902692]),
#  'stld': array([0.43342889]),
#  'musa': array([0.43068164]),
#  'fr': array([0.43019589]),
#  'eqt': array([0.42878643]),
#  'cnx': array([0.42823698]),
#  'tex': array([0.42776716]),
#  'ue': array([0.4273929]),
#  'cien': array([0.42720178]),
#  'sfm': array([0.426939]),
#  'bdc': array([0.423706]),
#  'crs': array([0.42287785]),
#  'clb': array([0.42246377]),
#  'cohr': array([0.42240006]),
#  'tr': array([0.41994744]),
#  'mdrx': array([0.41910336]),
#  'cone': array([0.4171763]),
#  'mlhr': array([0.41634814]),
#  'ths': array([0.41522535]),
#  'tgna': array([0.41470776]),
#  'wtrg': array([0.41312311]),
#  'eme': array([0.41274088]),
#  'smtc': array([0.41268514]),
#  'amg': array([0.41161013]),
#  'mtdr': array([0.41005733]),
#  'hni': array([0.406896]),
#  'manh': array([0.40586877]),
#  'pnm': array([0.40583692]),
#  'aciw': array([0.40547858]),
#  'ayi': array([0.40531932]),
#  'jef': array([0.40483357]),
#  'crus': array([0.40453098]),
#  'fhn': array([0.40414079]),
#  'kmpr': array([0.40277114]),
#  'nati': array([0.40249244]),
#  'ptc': array([0.40107501]),
#  'fhi': array([0.40087594]),
#  'saic': array([0.40014333]),
#  'moh': array([0.39914795]),
#  'man': array([0.39636089]),
#  'lstr': array([0.39511069]),
#  'caty': array([0.39458513]),
#  'ati': array([0.39387641]),
#  'ryn': array([0.39385252]),
#  'idcc': array([0.39156713]),
#  'jw a': array([0.3912725]),
#  'ubsi': array([0.39050008]),
#  'pb': array([0.38921803]),
#  'mcy': array([0.38897914]),
#  'slgn': array([0.38827043]),
#  'gef': array([0.38663004]),
#  'wri': array([0.38631948]),
#  'mpw': array([0.38629559]),
#  'ohi': array([0.38539576]),
#  'wbs': array([0.38506132]),
#  'avnt': array([0.38363593]),
#  'pzza': array([0.38343685]),
#  'gatx': array([0.38259277]),
#  'neu': array([0.38236184]),
#  'cor': array([0.38184424]),
#  'cgnx': array([0.38097627]),
#  'son': array([0.37994904]),
#  'ogs': array([0.37959866]),
#  'cbt': array([0.37898551]),
#  'atr': array([0.37771938]),
#  'trn': array([0.37583214]),
#  'sbh': array([0.37558528]),
#  'thc': array([0.37313266]),
#  'homb': array([0.37286192]),
#  'wpx': array([0.3726947]),
#  'fds': array([0.37119764]),
#  'achc': array([0.36999522]),
#  'jack': array([0.36856187]),
#  'vsat': array([0.36637203]),
#  'synh': array([0.3657748]),
#  'hrc': array([0.36555184]),
#  'post': array([0.36434942]),
#  'ingr': array([0.36403886]),
#  'gnw': array([0.36343367]),
#  'lamr': array([0.36273292]),
#  'cree': array([0.36178532]),
#  'clh': array([0.359914]),
#  'njr': array([0.3592451]),
#  'rnr': array([0.35883899]),
#  'ntct': array([0.35879917]),
#  'wtfc': array([0.35730212]),
#  'nycb': array([0.35619525]),
#  'cbrl': array([0.35554228]),
#  'pdco': array([0.35315337]),
#  'afg': array([0.35270744]),
#  'mms': array([0.35239688]),
#  'cvlt': array([0.35140946]),
#  'tds': array([0.35105112]),
#  'cri': array([0.35062112]),
#  'dnow': array([0.35010352]),
#  'hr': array([0.34819239]),
#  'tcf': array([0.3479535]),
#  'vvv': array([0.34784998]),
#  'itt': array([0.34604236]),
#  'urbn': array([0.34434623]),
#  'ash': array([0.34410734]),
#  'dci': array([0.34322344]),
#  'skx': array([0.34317566]),
#  'avns': array([0.34146361]),
#  'acc': array([0.34005415]),
#  'tpx': array([0.33967989]),
#  'ev': array([0.33694856]),
#  'ufs': array([0.33589744]),
#  'vsh': array([0.33518076]),
#  'wern': array([0.33504539]),
#  'osk': array([0.33220258]),
#  'he': array([0.33150979]),
#  'vmi': array([0.33063386]),
#  'lpx': array([0.32966237]),
#  'kmt': array([0.3288581]),
#  'ccmp': array([0.32806179]),
#  'pii': array([0.32795031]),
#  'seic': array([0.3276079]),
#  'epr': array([0.32705845]),
#  'kbr': array([0.32644529]),
#  'tyl': array([0.32584806]),
#  'hele': array([0.32154005]),
#  'tech': array([0.32095079]),
#  'nyt': array([0.31918299]),
#  'oi': array([0.31910336]),
#  'jcom': array([0.3180602]),
#  'ida': array([0.31758242]),
#  'pnfp': array([0.31430164]),
#  'cno': array([0.31325848]),
#  'cuz': array([0.3130594]),
#  'agco': array([0.31283644]),
#  'car': array([0.31228699]),
#  'gntx': array([0.31214365]),
#  'sf': array([0.31007326]),
#  'masi': array([0.30861602]),
#  'cw': array([0.30809842]),
#  'x': array([0.30770823]),
#  'ozk': array([0.30703137]),
#  'cdk': array([0.30660137]),
#  'jhg': array([0.30652174]),
#  'flo': array([0.30608377]),
#  'bc': array([0.30550247]),
#  'cli': array([0.30503265]),
#  'lfus': array([0.30391782]),
#  'cr': array([0.30367893]),
#  'nfg': array([0.30363115]),
#  'nuva': array([0.30359134]),
#  'wen': array([0.30355152]),
#  'pool': array([0.30292244]),
#  'tcbi': array([0.30230928]),
#  'oln': array([0.3005813]),
#  'rga': array([0.30032649]),
#  'acm': array([0.30014333]),
#  'sci': array([0.29966555]),
#  'slab': array([0.29877369]),
#  'geo': array([0.29787387]),
#  'aan': array([0.29767479]),
#  'lanc': array([0.29523013]),
#  'ttc': array([0.29485587]),
#  'stl': array([0.2947205]),
#  'an': array([0.2911212]),
#  'wst': array([0.29034878]),
#  'six': array([0.29034082]),
#  'jll': array([0.28778468]),
#  'fslr': array([0.28729097]),
#  'dnkn': array([0.28623188]),
#  'bkh': array([0.28455168]),
#  'casy': array([0.28303074]),
#  'clgx': array([0.27954292]),
#  'sbra': array([0.27823698]),
#  'wso': array([0.2778229]),
#  'dds': array([0.27771938]),
#  'fl': array([0.27653289]),
#  'leco': array([0.27395286]),
#  'pbh': array([0.27255932]),
#  'cbsh': array([0.27240803]),
#  'hiw': array([0.27152413]),
#  'fico': array([0.27064023]),
#  'ehc': array([0.26965281]),
#  'exp': array([0.26960503]),
#  'rbc': array([0.26746297]),
#  'dy': array([0.26716834]),
#  'dan': array([0.26379201]),
#  'mksi': array([0.26292403]),
#  'ndsn': array([0.26282051]),
#  'ramp': array([0.2626294]),
#  'cmc': array([0.25855232]),
#  'atge': array([0.25854435]),
#  'wsm': array([0.25848065]),
#  'sbny': array([0.25817009]),
#  'srcl': array([0.2579949]),
#  'pch': array([0.2533843]),
#  'tph': array([0.25209428]),
#  'umbf': array([0.25179169]),
#  'dpz': array([0.24894888]),
#  'byd': array([0.24804109]),
#  'cpt': array([0.24681478]),
#  'thg': array([0.24590699]),
#  'r': array([0.24136009]),
#  'trmb': array([0.2383182]),
#  'deck': array([0.23745819]),
#  'hubb': array([0.23518872]),
#  'mtx': array([0.23295111]),
#  'ens': array([0.23277592]),
#  'sfix': array([0.23180443]),
#  'mdu': array([0.23175665]),
#  'sam': array([0.22991718]),
#  'lsi': array([0.22801401]),
#  'sgms': array([0.2225434]),
#  'wor': array([0.22169135]),
#  'tkr': array([0.21918299]),
#  'eat': array([0.21873706]),
#  'slm': array([0.21783724]),
#  'tol': array([0.2171763]),
#  'bro': array([0.2147635]),
#  'mpwr': array([0.21013696]),
#  'jbl': array([0.20865584]),
#  'bio': array([0.20788342]),
#  'rpm': array([0.20767638]),
#  'cabo': array([0.20695971]),
#  'snx': array([0.20649785]),
#  'syna': array([0.20590858]),
#  'dks': array([0.19477624]),
#  'lii': array([0.19462494]),
#  'rs': array([0.18653448]),
#  'sxt': array([0.18395445]),
#  'cmp': array([0.17810161]),
#  'kbh': array([0.17680363]),
#  'uthr': array([0.17395286]),
#  'ggg': array([0.17229654]),
#  'crl': array([0.16887243]),
#  'ctlt': array([0.16615703]),
#  'msa': array([0.16320274]),
#  'arw': array([0.15481765]),
#  'nus': array([0.14364548]),
#  'bbby': array([0.06618092])}

# %%
# import datetime
from datetime import datetime
from yahoo_earnings_calendar import YahooEarningsCalendar
import math

my_custom_delay_s = 0.01

yec = YahooEarningsCalendar(my_custom_delay_s)

# Returns the next earnings date of BOX in Unix timestamp
#print(yec.get_next_earnings_date('box'))
# 1508716800

ticker_date = {}
sml_tickers = []
today=datetime.today()
start=today+timedelta(days=14)
#end=today+timedelta(days=16)
end=today+timedelta(days=18)


for ticker in set(existing_reports):
    pred_features = combined[ticker][-1:][cols]
    prediction = estimatorCopy.predict_proba(pred_features)[:,1]
    index = str(ticker)+':'+str(math.floor(100*prediction))

    try:
        date = datetime.fromtimestamp(yec.get_next_earnings_date(ticker))
        ticker_date[index] = date
        if date>start and date<end:
            sml_tickers.append(ticker)
    except:
        ticker_date[index] = datetime(1000, 1, 1, 1, 1)


{k: v for k, v in sorted(ticker_date.items(), key=lambda item: item[1])}
# Out:
# {'vvv:31': datetime.datetime(1000, 1, 1, 1, 1),
#  'jw a:21': datetime.datetime(1000, 1, 1, 1, 1),
#  'nfg:30': datetime.datetime(1000, 1, 1, 1, 1),
#  'casy:53': datetime.datetime(1000, 1, 1, 1, 1),
#  'alex:22': datetime.datetime(2020, 7, 30, 6, 0),
#  'stl:43': datetime.datetime(2021, 1, 20, 6, 0),
#  'tcf:42': datetime.datetime(2021, 1, 22, 6, 0),
#  'cr:26': datetime.datetime(2021, 1, 25, 6, 0),
#  'cohr:28': datetime.datetime(2021, 1, 26, 6, 0),
#  'snv:25': datetime.datetime(2021, 1, 26, 6, 0),
#  'pii:19': datetime.datetime(2021, 1, 26, 6, 0),
#  'umbf:41': datetime.datetime(2021, 1, 26, 6, 0),
#  'trmk:8': datetime.datetime(2021, 1, 26, 6, 0),
#  'slgn:18': datetime.datetime(2021, 1, 26, 6, 0),
#  'rnr:39': datetime.datetime(2021, 1, 26, 6, 0),
#  'ehc:47': datetime.datetime(2021, 1, 26, 6, 0),
#  'caty:26': datetime.datetime(2021, 1, 27, 6, 0),
#  'pb:37': datetime.datetime(2021, 1, 27, 6, 0),
#  'seic:40': datetime.datetime(2021, 1, 27, 6, 0),
#  'cree:24': datetime.datetime(2021, 1, 27, 6, 0),
#  'nycb:25': datetime.datetime(2021, 1, 27, 6, 0),
#  'ptc:23': datetime.datetime(2021, 1, 27, 6, 0),
#  'osk:22': datetime.datetime(2021, 1, 27, 6, 0),
#  'clb:23': datetime.datetime(2021, 1, 27, 6, 0),
#  'ter:14': datetime.datetime(2021, 1, 27, 6, 0),
#  'avt:25': datetime.datetime(2021, 1, 27, 6, 0),
#  'ubsi:26': datetime.datetime(2021, 1, 27, 6, 0),
#  'eat:28': datetime.datetime(2021, 1, 27, 6, 0),
#  'slm:34': datetime.datetime(2021, 1, 27, 6, 0),
#  'lstr:31': datetime.datetime(2021, 1, 27, 6, 0),
#  'knx:18': datetime.datetime(2021, 1, 27, 6, 0),
#  'cvlt:32': datetime.datetime(2021, 1, 27, 6, 0),
#  'mksi:39': datetime.datetime(2021, 1, 27, 6, 0),
#  'mur:14': datetime.datetime(2021, 1, 28, 6, 0),
#  'cnx:32': datetime.datetime(2021, 1, 28, 6, 0),
#  'kex:19': datetime.datetime(2021, 1, 28, 6, 0),
#  'x:19': datetime.datetime(2021, 1, 28, 6, 0),
#  'fhi:40': datetime.datetime(2021, 1, 28, 6, 0),
#  'ntct:34': datetime.datetime(2021, 1, 28, 6, 0),
#  'bc:32': datetime.datetime(2021, 1, 28, 6, 0),
#  'fico:48': datetime.datetime(2021, 1, 28, 6, 0),
#  'exp:42': datetime.datetime(2021, 1, 28, 6, 0),
#  'vly:19': datetime.datetime(2021, 1, 28, 6, 0),
#  'nati:30': datetime.datetime(2021, 1, 28, 6, 0),
#  'ori:28': datetime.datetime(2021, 1, 28, 6, 0),
#  'gatx:25': datetime.datetime(2021, 1, 28, 6, 0),
#  'jblu:29': datetime.datetime(2021, 1, 28, 6, 0),
#  'oln:32': datetime.datetime(2021, 1, 28, 6, 0),
#  'crs:25': datetime.datetime(2021, 1, 28, 6, 0),
#  'cfr:14': datetime.datetime(2021, 1, 28, 6, 0),
#  'ati:31': datetime.datetime(2021, 1, 28, 6, 0),
#  'ewbc:22': datetime.datetime(2021, 1, 28, 6, 0),
#  'gntx:38': datetime.datetime(2021, 1, 29, 6, 0),
#  'sf:37': datetime.datetime(2021, 1, 29, 6, 0),
#  'cbt:38': datetime.datetime(2021, 2, 1, 6, 0),
#  'crus:29': datetime.datetime(2021, 2, 1, 6, 0),
#  'rbc:34': datetime.datetime(2021, 2, 1, 6, 0),
#  'kmt:14': datetime.datetime(2021, 2, 1, 6, 0),
#  'pch:50': datetime.datetime(2021, 2, 1, 6, 0),
#  'kmpr:35': datetime.datetime(2021, 2, 1, 6, 0),
#  'krc:20': datetime.datetime(2021, 2, 1, 6, 0),
#  'wwd:22': datetime.datetime(2021, 2, 1, 6, 0),
#  'amg:20': datetime.datetime(2021, 2, 1, 6, 0),
#  'hubb:37': datetime.datetime(2021, 2, 2, 6, 0),
#  'gnw:41': datetime.datetime(2021, 2, 2, 6, 0),
#  'atge:21': datetime.datetime(2021, 2, 2, 6, 0),
#  'manh:30': datetime.datetime(2021, 2, 2, 6, 0),
#  'lii:26': datetime.datetime(2021, 2, 2, 6, 0),
#  'ctlt:28': datetime.datetime(2021, 2, 2, 6, 0),
#  'tech:31': datetime.datetime(2021, 2, 2, 6, 0),
#  'man:41': datetime.datetime(2021, 2, 2, 6, 0),
#  'ohi:34': datetime.datetime(2021, 2, 3, 6, 0),
#  'thg:40': datetime.datetime(2021, 2, 3, 6, 0),
#  'afg:26': datetime.datetime(2021, 2, 3, 6, 0),
#  'jhg:20': datetime.datetime(2021, 2, 3, 6, 0),
#  'ash:27': datetime.datetime(2021, 2, 3, 6, 0),
#  'ingr:30': datetime.datetime(2021, 2, 3, 6, 0),
#  'musa:22': datetime.datetime(2021, 2, 3, 6, 0),
#  'ryn:21': datetime.datetime(2021, 2, 3, 6, 0),
#  'neu:23': datetime.datetime(2021, 2, 3, 6, 0),
#  'mdu:38': datetime.datetime(2021, 2, 3, 6, 0),
#  'ccmp:36': datetime.datetime(2021, 2, 3, 6, 0),
#  'ugi:23': datetime.datetime(2021, 2, 3, 6, 0),
#  'lfus:41': datetime.datetime(2021, 2, 3, 6, 0),
#  'slab:29': datetime.datetime(2021, 2, 3, 6, 0),
#  'smg:30': datetime.datetime(2021, 2, 3, 6, 0),
#  'flo:22': datetime.datetime(2021, 2, 3, 6, 0),
#  'rgld:30': datetime.datetime(2021, 2, 3, 6, 0),
#  'nyt:32': datetime.datetime(2021, 2, 4, 6, 0),
#  'post:35': datetime.datetime(2021, 2, 4, 6, 0),
#  'dlx:34': datetime.datetime(2021, 2, 4, 6, 0),
#  'arw:57': datetime.datetime(2021, 2, 4, 6, 0),
#  'hain:23': datetime.datetime(2021, 2, 4, 6, 0),
#  'vsat:32': datetime.datetime(2021, 2, 4, 6, 0),
#  'mpwr:25': datetime.datetime(2021, 2, 4, 6, 0),
#  'dnkn:29': datetime.datetime(2021, 2, 4, 6, 0),
#  'tkr:44': datetime.datetime(2021, 2, 4, 6, 0),
#  'mdp:29': datetime.datetime(2021, 2, 4, 6, 0),
#  'mtx:13': datetime.datetime(2021, 2, 4, 6, 0),
#  'syna:39': datetime.datetime(2021, 2, 4, 6, 0),
#  'cor:34': datetime.datetime(2021, 2, 4, 6, 0),
#  'ofc:32': datetime.datetime(2021, 2, 4, 6, 0),
#  'mpw:25': datetime.datetime(2021, 2, 4, 6, 0),
#  'csl:30': datetime.datetime(2021, 2, 4, 6, 0),
#  'lanc:30': datetime.datetime(2021, 2, 4, 6, 0),
#  'mms:24': datetime.datetime(2021, 2, 4, 6, 0),
#  'cpt:39': datetime.datetime(2021, 2, 4, 6, 0),
#  'agco:24': datetime.datetime(2021, 2, 4, 6, 0),
#  'sbh:25': datetime.datetime(2021, 2, 4, 6, 0),
#  'pten:18': datetime.datetime(2021, 2, 4, 6, 0),
#  'deck:47': datetime.datetime(2021, 2, 4, 6, 0),
#  'tdc:32': datetime.datetime(2021, 2, 4, 6, 0),
#  'wern:40': datetime.datetime(2021, 2, 4, 6, 0),
#  'skx:31': datetime.datetime(2021, 2, 4, 6, 0),
#  'njr:28': datetime.datetime(2021, 2, 4, 6, 0),
#  'pbh:39': datetime.datetime(2021, 2, 4, 6, 0),
#  'hrc:21': datetime.datetime(2021, 2, 5, 6, 0),
#  'enr:13': datetime.datetime(2021, 2, 8, 6, 0),
#  'blkb:23': datetime.datetime(2021, 2, 8, 6, 0),
#  'rga:25': datetime.datetime(2021, 2, 8, 6, 0),
#  'cmp:49': datetime.datetime(2021, 2, 8, 6, 0),
#  'acm:43': datetime.datetime(2021, 2, 8, 6, 0),
#  'cdk:34': datetime.datetime(2021, 2, 8, 6, 0),
#  'tco:24': datetime.datetime(2021, 2, 8, 6, 0),
#  'ramp:45': datetime.datetime(2021, 2, 8, 6, 0),
#  'epc:19': datetime.datetime(2021, 2, 9, 6, 0),
#  'cno:39': datetime.datetime(2021, 2, 9, 6, 0),
#  'vsh:24': datetime.datetime(2021, 2, 9, 6, 0),
#  'hiw:35': datetime.datetime(2021, 2, 9, 6, 0),
#  'avnt:20': datetime.datetime(2021, 2, 9, 6, 0),
#  'lpx:33': datetime.datetime(2021, 2, 9, 6, 0),
#  'oi:40': datetime.datetime(2021, 2, 9, 6, 0),
#  'nnn:23': datetime.datetime(2021, 2, 9, 6, 0),
#  'thc:27': datetime.datetime(2021, 2, 9, 6, 0),
#  'bkh:41': datetime.datetime(2021, 2, 9, 6, 0),
#  'pri:19': datetime.datetime(2021, 2, 9, 6, 0),
#  'ncr:23': datetime.datetime(2021, 2, 9, 6, 0),
#  'dei:29': datetime.datetime(2021, 2, 9, 6, 0),
#  'jll:34': datetime.datetime(2021, 2, 9, 6, 0),
#  'geo:38': datetime.datetime(2021, 2, 10, 6, 0),
#  'trmb:37': datetime.datetime(2021, 2, 10, 6, 0),
#  'hr:41': datetime.datetime(2021, 2, 10, 6, 0),
#  'moh:28': datetime.datetime(2021, 2, 10, 6, 0),
#  'tyl:31': datetime.datetime(2021, 2, 10, 6, 0),
#  'tr:22': datetime.datetime(2021, 2, 10, 6, 0),
#  'fr:30': datetime.datetime(2021, 2, 10, 6, 0),
#  'cxw:13': datetime.datetime(2021, 2, 10, 6, 0),
#  'bdc:20': datetime.datetime(2021, 2, 10, 6, 0),
#  'ens:50': datetime.datetime(2021, 2, 10, 6, 0),
#  'tpx:26': datetime.datetime(2021, 2, 11, 6, 0),
#  'ths:18': datetime.datetime(2021, 2, 11, 6, 0),
#  'mac:21': datetime.datetime(2021, 2, 11, 6, 0),
#  'ufs:36': datetime.datetime(2021, 2, 11, 6, 0),
#  'tex:26': datetime.datetime(2021, 2, 11, 6, 0),
#  'cuz:45': datetime.datetime(2021, 2, 11, 6, 0),
#  'wex:20': datetime.datetime(2021, 2, 11, 6, 0),
#  'cc:19': datetime.datetime(2021, 2, 11, 6, 0),
#  'r:29': datetime.datetime(2021, 2, 11, 6, 0),
#  'cgnx:27': datetime.datetime(2021, 2, 11, 6, 0),
#  'wst:24': datetime.datetime(2021, 2, 11, 6, 0),
#  'son:37': datetime.datetime(2021, 2, 11, 6, 0),
#  'nus:45': datetime.datetime(2021, 2, 11, 6, 0),
#  'pool:25': datetime.datetime(2021, 2, 11, 6, 0),
#  'bio:55': datetime.datetime(2021, 2, 11, 6, 0),
#  'wso:23': datetime.datetime(2021, 2, 11, 6, 0),
#  'jcom:32': datetime.datetime(2021, 2, 11, 6, 0),
#  'faf:29': datetime.datetime(2021, 2, 11, 6, 0),
#  'pbf:18': datetime.datetime(2021, 2, 11, 6, 0),
#  'leco:35': datetime.datetime(2021, 2, 12, 6, 0),
#  'sxt:15': datetime.datetime(2021, 2, 12, 6, 0),
#  'rig:14': datetime.datetime(2021, 2, 15, 6, 0),
#  'sci:20': datetime.datetime(2021, 2, 15, 6, 0),
#  'an:38': datetime.datetime(2021, 2, 16, 6, 0),
#  'sgms:23': datetime.datetime(2021, 2, 16, 6, 0),
#  'car:17': datetime.datetime(2021, 2, 16, 6, 0),
#  'acc:36': datetime.datetime(2021, 2, 16, 6, 0),
#  'mcy:37': datetime.datetime(2021, 2, 16, 6, 0),
#  'he:34': datetime.datetime(2021, 2, 16, 6, 0),
#  'byd:51': datetime.datetime(2021, 2, 16, 6, 0),
#  'lsi:36': datetime.datetime(2021, 2, 17, 6, 0),
#  'sam:28': datetime.datetime(2021, 2, 17, 6, 0),
#  'wri:36': datetime.datetime(2021, 2, 17, 6, 0),
#  'ale:19': datetime.datetime(2021, 2, 17, 6, 0),
#  'crl:44': datetime.datetime(2021, 2, 17, 6, 0),
#  'dnow:25': datetime.datetime(2021, 2, 17, 6, 0),
#  'hni:35': datetime.datetime(2021, 2, 17, 6, 0),
#  'vmi:39': datetime.datetime(2021, 2, 17, 6, 0),
#  'cake:35': datetime.datetime(2021, 2, 17, 6, 0),
#  'ndsn:50': datetime.datetime(2021, 2, 17, 6, 0),
#  'skt:26': datetime.datetime(2021, 2, 17, 6, 0),
#  'jack:31': datetime.datetime(2021, 2, 17, 6, 0),
#  'ue:20': datetime.datetime(2021, 2, 17, 6, 0),
#  'ogs:25': datetime.datetime(2021, 2, 17, 6, 0),
#  'msa:18': datetime.datetime(2021, 2, 17, 6, 0),
#  'trn:33': datetime.datetime(2021, 2, 17, 6, 0),
#  'cone:28': datetime.datetime(2021, 2, 17, 6, 0),
#  'fslr:41': datetime.datetime(2021, 2, 18, 6, 0),
#  'aan:38': datetime.datetime(2021, 2, 18, 6, 0),
#  'nuva:35': datetime.datetime(2021, 2, 18, 6, 0),
#  'rs:44': datetime.datetime(2021, 2, 18, 6, 0),
#  'dan:32': datetime.datetime(2021, 2, 18, 6, 0),
#  'synh:32': datetime.datetime(2021, 2, 18, 6, 0),
#  'idcc:18': datetime.datetime(2021, 2, 18, 6, 0),
#  'txrh:17': datetime.datetime(2021, 2, 18, 6, 0),
#  'six:34': datetime.datetime(2021, 2, 18, 6, 0),
#  'kbr:38': datetime.datetime(2021, 2, 18, 6, 0),
#  'tds:20': datetime.datetime(2021, 2, 18, 6, 0),
#  'ida:38': datetime.datetime(2021, 2, 18, 6, 0),
#  'md:24': datetime.datetime(2021, 2, 18, 6, 0),
#  'atr:32': datetime.datetime(2021, 2, 18, 6, 0),
#  'tph:27': datetime.datetime(2021, 2, 18, 6, 0),
#  'gmed:36': datetime.datetime(2021, 2, 18, 6, 0),
#  'cnk:18': datetime.datetime(2021, 2, 19, 6, 0),
#  'itt:40': datetime.datetime(2021, 2, 19, 6, 0),
#  'sbra:31': datetime.datetime(2021, 2, 22, 6, 0),
#  'sfm:25': datetime.datetime(2021, 2, 22, 6, 0),
#  'cri:37': datetime.datetime(2021, 2, 22, 6, 0),
#  'masi:42': datetime.datetime(2021, 2, 23, 6, 0),
#  'jbgs:25': datetime.datetime(2021, 2, 23, 6, 0),
#  'tol:52': datetime.datetime(2021, 2, 23, 6, 0),
#  'avns:20': datetime.datetime(2021, 2, 23, 6, 0),
#  'bco:27': datetime.datetime(2021, 2, 23, 6, 0),
#  'fcn:24': datetime.datetime(2021, 2, 23, 6, 0),
#  'cbrl:35': datetime.datetime(2021, 2, 23, 6, 0),
#  'mtdr:18': datetime.datetime(2021, 2, 23, 6, 0),
#  'y:23': datetime.datetime(2021, 2, 23, 6, 0),
#  'dds:33': datetime.datetime(2021, 2, 23, 6, 0),
#  'pzza:19': datetime.datetime(2021, 2, 24, 6, 0),
#  'cli:41': datetime.datetime(2021, 2, 24, 6, 0),
#  'cw:45': datetime.datetime(2021, 2, 24, 6, 0),
#  'chdn:25': datetime.datetime(2021, 2, 24, 6, 0),
#  'ev:40': datetime.datetime(2021, 2, 24, 6, 0),
#  'livn:24': datetime.datetime(2021, 2, 24, 6, 0),
#  'sabr:36': datetime.datetime(2021, 2, 24, 6, 0),
#  'wpx:25': datetime.datetime(2021, 2, 24, 6, 0),
#  'amcx:25': datetime.datetime(2021, 2, 24, 6, 0),
#  'dy:26': datetime.datetime(2021, 2, 24, 6, 0),
#  'epr:26': datetime.datetime(2021, 2, 24, 6, 0),
#  'clgx:48': datetime.datetime(2021, 2, 24, 6, 0),
#  'uthr:56': datetime.datetime(2021, 2, 24, 6, 0),
#  'ghc:32': datetime.datetime(2021, 2, 24, 6, 0),
#  'clh:29': datetime.datetime(2021, 2, 24, 6, 0),
#  'swx:28': datetime.datetime(2021, 2, 24, 6, 0),
#  'wen:33': datetime.datetime(2021, 2, 24, 6, 0),
#  'gef:33': datetime.datetime(2021, 2, 24, 6, 0),
#  'wtrg:29': datetime.datetime(2021, 2, 24, 6, 0),
#  'int:32': datetime.datetime(2021, 2, 25, 6, 0),
#  'pdco:29': datetime.datetime(2021, 2, 25, 6, 0),
#  'safm:12': datetime.datetime(2021, 2, 25, 6, 0),
#  'dpz:47': datetime.datetime(2021, 2, 25, 6, 0),
#  'eme:29': datetime.datetime(2021, 2, 25, 6, 0),
#  'iboc:12': datetime.datetime(2021, 2, 25, 6, 0),
#  'eqt:21': datetime.datetime(2021, 2, 25, 6, 0),
#  'oge:13': datetime.datetime(2021, 2, 25, 6, 0),
#  'srcl:31': datetime.datetime(2021, 2, 25, 6, 0),
#  'achc:34': datetime.datetime(2021, 2, 25, 6, 0),
#  'aciw:30': datetime.datetime(2021, 2, 25, 6, 0),
#  'cabo:47': datetime.datetime(2021, 2, 25, 6, 0),
#  'pnm:28': datetime.datetime(2021, 2, 26, 6, 0),
#  'fl:16': datetime.datetime(2021, 2, 26, 6, 0),
#  'svc:20': datetime.datetime(2021, 2, 26, 6, 0),
#  'lamr:27': datetime.datetime(2021, 2, 26, 6, 0),
#  'urbn:35': datetime.datetime(2021, 3, 1, 6, 0),
#  'dhc:15': datetime.datetime(2021, 3, 1, 6, 0),
#  'tgna:32': datetime.datetime(2021, 3, 1, 6, 0),
#  'mdrx:40': datetime.datetime(2021, 3, 1, 6, 0),
#  'aeo:25': datetime.datetime(2021, 3, 2, 6, 0),
#  'ttc:39': datetime.datetime(2021, 3, 3, 6, 0),
#  'cien:26': datetime.datetime(2021, 3, 3, 6, 0),
#  'dci:43': datetime.datetime(2021, 3, 3, 6, 0),
#  'tho:4': datetime.datetime(2021, 3, 8, 6, 0),
#  'dks:46': datetime.datetime(2021, 3, 8, 6, 0),
#  'sfix:40': datetime.datetime(2021, 3, 8, 6, 0),
#  'smtc:22': datetime.datetime(2021, 3, 9, 6, 0),
#  'jbl:41': datetime.datetime(2021, 3, 11, 6, 0),
#  'mlhr:29': datetime.datetime(2021, 3, 16, 6, 0),
#  'wsm:35': datetime.datetime(2021, 3, 16, 6, 0),
#  'cmc:44': datetime.datetime(2021, 3, 17, 6, 0),
#  'snx:34': datetime.datetime(2021, 3, 22, 6, 0),
#  'saic:30': datetime.datetime(2021, 3, 24, 6, 0),
#  'wor:24': datetime.datetime(2021, 3, 24, 6, 0),
#  'fds:15': datetime.datetime(2021, 3, 24, 6, 0),
#  'jef:40': datetime.datetime(2021, 3, 24, 6, 0),
#  'kbh:42': datetime.datetime(2021, 3, 24, 6, 0),
#  'ayi:37': datetime.datetime(2021, 3, 31, 6, 0),
#  'rpm:41': datetime.datetime(2021, 4, 6, 6, 0),
#  'msm:14': datetime.datetime(2021, 4, 7, 6, 0),
#  'bbby:19': datetime.datetime(2021, 4, 13, 6, 0),
#  'homb:30': datetime.datetime(2021, 4, 14, 6, 0),
#  'wbs:24': datetime.datetime(2021, 4, 19, 6, 0),
#  'fhn:35': datetime.datetime(2021, 4, 19, 6, 0),
#  'stld:20': datetime.datetime(2021, 4, 19, 6, 0),
#  'wtfc:39': datetime.datetime(2021, 4, 19, 6, 0),
#  'pnfp:35': datetime.datetime(2021, 4, 19, 6, 0),
#  'fult:19': datetime.datetime(2021, 4, 19, 6, 0),
#  'pacw:16': datetime.datetime(2021, 4, 19, 6, 0),
#  'wafd:19': datetime.datetime(2021, 4, 19, 6, 0),
#  'boh:18': datetime.datetime(2021, 4, 19, 6, 0),
#  'bxs:22': datetime.datetime(2021, 4, 19, 6, 0),
#  'umpq:30': datetime.datetime(2021, 4, 20, 6, 0),
#  'ggg:57': datetime.datetime(2021, 4, 20, 6, 0),
#  'tcbi:35': datetime.datetime(2021, 4, 20, 6, 0),
#  'sbny:29': datetime.datetime(2021, 4, 21, 6, 0),
#  'asb:25': datetime.datetime(2021, 4, 21, 6, 0),
#  'fnb:25': datetime.datetime(2021, 4, 21, 6, 0),
#  'ozk:36': datetime.datetime(2021, 4, 21, 6, 0),
#  'bro:36': datetime.datetime(2021, 4, 26, 6, 0),
#  'hwc:24': datetime.datetime(2021, 4, 26, 6, 0),
#  'hele:42': datetime.datetime(2021, 4, 26, 6, 0),
#  'cbsh:41': datetime.datetime(2021, 4, 26, 6, 0)}

# %%
df = pd.DataFrame(sml_tickers)
writer = pd.ExcelWriter('mid_tickers.xlsx', engine='xlsxwriter')
df.to_excel(writer, sheet_name='welcome', index=False)
writer.save()

# %%
len(df)
# Out:
# 20

# %%
df
# Out:
#        0
# 0    cno
# 1    ncr
# 2    thc
# 3    jll
# 4    hiw
# 5    rga
# 6     oi
# 7   avnt
# 8   blkb
# 9    enr
# 10   epc
# 11   vsh
# 12   nnn
# 13   tco
# 14   lpx
# 15   bkh
# 16   cmp
# 17   dei
# 18   pri
# 19   cdk
