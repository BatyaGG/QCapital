# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
plt.rcParams['figure.figsize'] = [12, 8]

# %%
trades = pd.read_csv('trades.csv')
print(trades)
# Out:
#      Ticker    Entry DT     Exit DT  Entry Price  Exit Price  Amount  \
# 0      SERO  2002-07-01  2002-07-02     19.66560   18.442610   -4943
# 1      UNWR  2002-07-01  2002-07-02      3.01896    2.945753   -7899
# 2      AGYS  2002-07-01  2002-07-02     11.33230   11.021863   -7285
# 3     MESAQ  2002-07-01  2002-07-02     10.16464    9.619023   -5659
# 4      BRKR  2002-07-01  2002-07-02      4.37624    4.408697   -9719
# ...     ...         ...         ...          ...         ...     ...
# 5586   CLZR  2003-08-07  2003-08-08      6.16730    6.731500     782
# 5587   ATSN  2003-08-07  2003-08-08      6.31760    6.282400    1105
# 5588   DKHR  2003-08-07  2003-08-08     13.55204   13.418100     556
# 5589   WTEL  2003-08-07  2003-08-08     13.69756   14.096191    -513
# 5590  MIRKQ  2003-08-07  2003-08-08      0.21458    0.210289   -7651
#
#               PNL   Trade %      MV %  diff_score  diff_score_dev  \
# 0     6045.241084  6.218932  0.604524    0.077091        1.932540
# ...

# %% [markdown]
# # Trade % dependency

# %% [markdown]
# ## diff_score

# %%
plt.plot(trades.diff_score, trades['Trade %'], '.')

# %% [markdown]
# ## diff_score_dev

# %%
plt.plot(trades.diff_score_dev, trades['Trade %'], '.')

# %% [markdown]
# ## cap

# %%
plt.plot(trades.cap, trades['Trade %'], '.')

# %% [markdown]
# ## cap_dev

# %%
plt.plot(trades.cap_dev, trades['Trade %'], '.')

# %% [markdown]
# ## vola

# %%
plt.plot(trades.vola, trades['Trade %'], '.')

# %% [markdown]
# ## vola_dev

# %%
plt.plot(trades.vola_dev, trades['Trade %'], '.')

# %% [markdown]
# ## inv_vola

# %%
plt.plot(trades.inv_vola, trades['Trade %'], '.')

# %% [markdown]
# ## inv_vola_norm

# %%
plt.plot(trades.inv_vola_norm, trades['Trade %'], '.')
